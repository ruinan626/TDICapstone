# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import model_selection, ensemble
sns.set()
import sklearn.metrics
import dill
import xgboost as xgb
import matplotlib

# %%
train = dill.load(open('trainETHUSDT.dill', 'rb'))
val = dill.load(open('valETHUSDT.dill', 'rb'))

# %%
def datapreview():
    l = [train,val]
    name = ['train','val']
    for i, k in enumerate(l):
        print(name[i])
        print(" ")
        print(k.shape)
        print(" ")
        print(name[i],k.count())

# %%
datapreview()
# Out:
# train
#
# (4229847, 50)
#
# train Unnamed: 0                                      4229847
# time_index                                      4229847
# label                                           4229847
# regular_Ceiling_Floors_15                       4229847
# regular_Trend_Speed_3                           4229847
# regular_Last2_trend                             4229847
# irregular_Dynamic_Pressure                      4229847
# irregular_liquid_orderbook_slope                4229847
# regular_Consecutive_Large_Order_Flow            4229847
# regular_Ceiling_Floors_9                        4229847
# regular_Ceiling_Floors_17                       4229847
# regular_Ceiling_Floors_13                       4229847
# irregular_liquid_update_rate                    4229847
# regular_current_trend_last_trend_ratio          4228696
# regular_mid_ma_diff                             4229847
# irregular_Large_Quote_EMA                       4229847
# irregular_liquid_rapid_change                   4229847
# regular_Ceiling_Floors_11                       4229847
# regular_ma_diff                                 4229847
# irregular_liquid_orderbook_density              4229847
# irregular_Mid_Last_diff_EMA                     4229847
# irregular_orderbook_slope_diff_EMA              4229847
# irregular_adjusted_ask_bid_amount_ratio_EMA     4229847
# regular_ma_diff_change                          4229847
# irregular_weighted_middle_price_diff            4229847
# regular_relevant_trend_BTCUSDT                  4229847
# regular_Min_Max_Position                        4228696
# irregular_ask_bid_amount_ratio_EMA              4229847
# irregular_liquid_orderbook_thickness            4229847
# irregular_liquid_rapid_inverse_change           4229847
# irregular_liquid_spread                         4229696
# irregular_weighted_middle_price_change          4229847
# irregular_bid_Pressure                          4229847
# regular_current_trend_last_large_trend_ratio    4228696
# regular_relevant_trend_ETHBTC                   4229847
# irregular_ask_Pressure                          4229847
# regular_Ceiling_Floors_3                        4229847
# regular_adjusted_current_trend                  4228638
# irregular_Consecutive_Large_Pressure            4229847
# regular_current_last2_ratio                     4228638
# regular_current_trend                           4229847
# regular_current_trend_speed                     4229847
# regular_MA_Tick_Return                          4229847
# regular_Ceiling_Floors_5                        4229847
# regular_last_last2_ratio                        4228638
# regular_liquid_current_amount                   4229847
# regular_Order_Flow_MA                           4229847
# regular_Ceiling_Floors_19                       4229847
# regular_Ceiling_Floors_7                        4229847
# irregular_liquid_hour                           4229847
# dtype: int64
# val
#
# (1977627, 50)
#
# val Unnamed: 0                                      1977627
# time_index                                      1977627
# label                                           1977627
# regular_Ceiling_Floors_15                       1977627
# regular_Trend_Speed_3                           1977627
# regular_Last2_trend                             1977627
# irregular_Dynamic_Pressure                      1977627
# irregular_liquid_orderbook_slope                1977627
# regular_Consecutive_Large_Order_Flow            1977627
# regular_Ceiling_Floors_9                        1977627
# regular_Ceiling_Floors_17                       1977627
# regular_Ceiling_Floors_13                       1977627
# irregular_liquid_update_rate                    1977627
# regular_current_trend_last_trend_ratio          1977012
# regular_mid_ma_diff                             1977627
# irregular_Large_Quote_EMA                       1977627
# irregular_liquid_rapid_change                   1977627
# regular_Ceiling_Floors_11                       1977627
# regular_ma_diff                                 1977627
# irregular_liquid_orderbook_density              1977627
# irregular_Mid_Last_diff_EMA                     1977627
# irregular_orderbook_slope_diff_EMA              1977627
# irregular_adjusted_ask_bid_amount_ratio_EMA     1977627
# regular_ma_diff_change                          1977627
# irregular_weighted_middle_price_diff            1977627
# regular_relevant_trend_BTCUSDT                  1977627
# regular_Min_Max_Position                        1977012
# irregular_ask_bid_amount_ratio_EMA              1977627
# irregular_liquid_orderbook_thickness            1977627
# irregular_liquid_rapid_inverse_change           1977627
# irregular_liquid_spread                               0
# irregular_weighted_middle_price_change          1977627
# irregular_bid_Pressure                          1977627
# regular_current_trend_last_large_trend_ratio    1977012
# regular_relevant_trend_ETHBTC                   1977627
# irregular_ask_Pressure                          1977627
# regular_Ceiling_Floors_3                        1977627
# regular_adjusted_current_trend                  1976752
# irregular_Consecutive_Large_Pressure            1977627
# regular_current_last2_ratio                     1976752
# regular_current_trend                           1977627
# regular_current_trend_speed                     1977627
# regular_MA_Tick_Return                          1977627
# regular_Ceiling_Floors_5                        1977627
# regular_last_last2_ratio                        1976752
# regular_liquid_current_amount                   1977627
# regular_Order_Flow_MA                           1977627
# regular_Ceiling_Floors_19                       1977627
# regular_Ceiling_Floors_7                        1977627
# irregular_liquid_hour                           1977627
# dtype: int64

# %%
def dropHighCorrFeatures(df):
    corr_matrix = df.corr().abs()
    upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
    to_drop = [column for column in upper.columns if any(upper[column] > 0.5)]
    df.drop(to_drop, axis=1,inplace=True)

# %%
def dfpreprocess(df):
    df.set_index('time_index',inplace=True)
    df.drop(['Unnamed: 0'], axis=1,inplace=True)
    #df.dropna(inplace = True)
    df.drop(['irregular_liquid_spread'], axis=1,inplace=True )
    df.fillna(df.mean(), inplace = True)
    #optional
    #dropHighCorrFeatures(df)
    
    y = df.label
    X = df[df.columns[1:]]
    return X, y

# %%
X0,y0 = dfpreprocess(train)
print(X0.shape)

X_test,y_test = dfpreprocess(val)
# Out:
# (4229847, 46)

# %%
X_train,y_train = X0[:3200000],y0[:3200000]
X_val, y_val = X0[3500000:], y0[3500000:]

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
print(X_val.shape)
print(y_val.shape)
#print(X_test2.shape)
# Out:
# (3200000, 46)
# (3200000,)
# (1977627, 46)
# (1977627,)
# (729847, 46)
# (729847,)

# %%
def checkAcc(predict, y_test):
    temp = np.multiply(predict, np.array(y_test))
    res = [i for i in temp if i > 0]
    acc = len(res)/len(predict)
    print("direction prediction accuracy", acc)
    return acc

# %% [markdown]
# ## XGBoost

# %%
dtrain = xgb.DMatrix(X_train,y_train)
dtest = xgb.DMatrix(X_test, y_test)
dval = xgb.DMatrix(X_val, y_val)

# %%
param = {'max_depth': 10, 'eta': 0.1, 'verbosity':2,'subsample':0.8}
param['nthread'] = 4
param['eval_metric'] = 'rmse'

evallist = [(dval, 'eval')]

# %%
num_round = 150
bst = xgb.train(param, dtrain, num_round, evallist, early_stopping_rounds=10)
# Out:
# [20:40:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=6
# [0]	eval-rmse:0.45010
# Will train until eval-rmse hasn't improved in 10 rounds.
# [20:40:10] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=6
# [1]	eval-rmse:0.40504
# [20:40:19] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=6
# [2]	eval-rmse:0.36451
# [20:40:28] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=6
# [3]	eval-rmse:0.32804
# [20:40:38] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=7
# [4]	eval-rmse:0.29524
# [20:40:48] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 34 extra nodes, 0 pruned nodes, max_depth=7
# [5]	eval-rmse:0.26572
# [20:40:57] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=7
# [6]	eval-rmse:0.23919
# [20:41:07] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 30 extra nodes, 0 pruned nodes, max_depth=6
# [7]	eval-rmse:0.21525
# [20:41:17] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 36 extra nodes, 0 pruned nodes, max_depth=7
# [8]	eval-rmse:0.19374
# [20:41:26] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 38 extra nodes, 0 pruned nodes, max_depth=7
# [9]	eval-rmse:0.17435
# [20:41:37] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 56 extra nodes, 0 pruned nodes, max_depth=8
# [10]	eval-rmse:0.15693
# [20:41:49] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 50 extra nodes, 0 pruned nodes, max_depth=9
# [11]	eval-rmse:0.14124
# [20:42:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 52 extra nodes, 0 pruned nodes, max_depth=9
# [12]	eval-rmse:0.12711
# [20:42:14] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 88 extra nodes, 0 pruned nodes, max_depth=10
# [13]	eval-rmse:0.11441
# [20:42:28] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 88 extra nodes, 0 pruned nodes, max_depth=10
# [14]	eval-rmse:0.10297
# [20:42:41] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 108 extra nodes, 0 pruned nodes, max_depth=10
# [15]	eval-rmse:0.09267
# [20:42:54] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=10
# [16]	eval-rmse:0.08341
# [20:43:08] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 174 extra nodes, 0 pruned nodes, max_depth=10
# [17]	eval-rmse:0.07507
# [20:43:21] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 158 extra nodes, 0 pruned nodes, max_depth=10
# [18]	eval-rmse:0.06757
# [20:43:35] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 188 extra nodes, 0 pruned nodes, max_depth=10
# [19]	eval-rmse:0.06081
# [20:43:48] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 196 extra nodes, 0 pruned nodes, max_depth=10
# [20]	eval-rmse:0.05474
# [20:44:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 230 extra nodes, 0 pruned nodes, max_depth=10
# [21]	eval-rmse:0.04927
# [20:44:16] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 274 extra nodes, 0 pruned nodes, max_depth=10
# [22]	eval-rmse:0.04435
# [20:44:30] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 280 extra nodes, 0 pruned nodes, max_depth=10
# [23]	eval-rmse:0.03992
# [20:44:45] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 346 extra nodes, 0 pruned nodes, max_depth=10
# [24]	eval-rmse:0.03593
# [20:44:58] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 254 extra nodes, 0 pruned nodes, max_depth=10
# [25]	eval-rmse:0.03235
# [20:45:13] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 432 extra nodes, 0 pruned nodes, max_depth=10
# [26]	eval-rmse:0.02912
# [20:45:27] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 398 extra nodes, 0 pruned nodes, max_depth=10
# [27]	eval-rmse:0.02622
# [20:45:42] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 498 extra nodes, 0 pruned nodes, max_depth=10
# [28]	eval-rmse:0.02361
# [20:45:56] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 384 extra nodes, 0 pruned nodes, max_depth=10
# [29]	eval-rmse:0.02125
# [20:46:10] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 454 extra nodes, 0 pruned nodes, max_depth=10
# [30]	eval-rmse:0.01914
# [20:46:25] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 658 extra nodes, 0 pruned nodes, max_depth=10
# [31]	eval-rmse:0.01724
# [20:46:40] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 522 extra nodes, 0 pruned nodes, max_depth=10
# [32]	eval-rmse:0.01553
# [20:46:55] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 834 extra nodes, 0 pruned nodes, max_depth=10
# [33]	eval-rmse:0.01400
# [20:47:10] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 740 extra nodes, 0 pruned nodes, max_depth=10
# [34]	eval-rmse:0.01261
# [20:47:25] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 878 extra nodes, 0 pruned nodes, max_depth=10
# [35]	eval-rmse:0.01137
# [20:47:40] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 746 extra nodes, 0 pruned nodes, max_depth=10
# [36]	eval-rmse:0.01026
# [20:47:55] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1064 extra nodes, 0 pruned nodes, max_depth=10
# [37]	eval-rmse:0.00925
# [20:48:10] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 888 extra nodes, 0 pruned nodes, max_depth=10
# [38]	eval-rmse:0.00836
# [20:48:26] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 848 extra nodes, 0 pruned nodes, max_depth=10
# [39]	eval-rmse:0.00755
# [20:48:41] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1010 extra nodes, 0 pruned nodes, max_depth=10
# [40]	eval-rmse:0.00683
# [20:48:57] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 838 extra nodes, 0 pruned nodes, max_depth=10
# [41]	eval-rmse:0.00618
# [20:49:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1058 extra nodes, 0 pruned nodes, max_depth=10
# [42]	eval-rmse:0.00560
# [20:49:27] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1036 extra nodes, 0 pruned nodes, max_depth=10
# [43]	eval-rmse:0.00508
# [20:49:43] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1186 extra nodes, 0 pruned nodes, max_depth=10
# [44]	eval-rmse:0.00462
# [20:49:57] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1060 extra nodes, 0 pruned nodes, max_depth=10
# [45]	eval-rmse:0.00421
# [20:50:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 800 extra nodes, 0 pruned nodes, max_depth=10
# [46]	eval-rmse:0.00385
# [20:50:28] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1128 extra nodes, 0 pruned nodes, max_depth=10
# [47]	eval-rmse:0.00353
# [20:50:43] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1342 extra nodes, 0 pruned nodes, max_depth=10
# [48]	eval-rmse:0.00325
# [20:50:58] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 928 extra nodes, 0 pruned nodes, max_depth=10
# [49]	eval-rmse:0.00300
# [20:51:13] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1280 extra nodes, 0 pruned nodes, max_depth=10
# [50]	eval-rmse:0.00278
# [20:51:29] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1148 extra nodes, 0 pruned nodes, max_depth=10
# [51]	eval-rmse:0.00259
# [20:51:44] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1336 extra nodes, 0 pruned nodes, max_depth=10
# [52]	eval-rmse:0.00242
# [20:52:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1376 extra nodes, 0 pruned nodes, max_depth=10
# [53]	eval-rmse:0.00228
# [20:52:15] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 936 extra nodes, 0 pruned nodes, max_depth=10
# [54]	eval-rmse:0.00216
# [20:52:29] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 958 extra nodes, 0 pruned nodes, max_depth=10
# [55]	eval-rmse:0.00205
# [20:52:45] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 938 extra nodes, 0 pruned nodes, max_depth=10
# [56]	eval-rmse:0.00196
# [20:52:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 956 extra nodes, 0 pruned nodes, max_depth=10
# [57]	eval-rmse:0.00189
# [20:53:14] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 768 extra nodes, 0 pruned nodes, max_depth=10
# [58]	eval-rmse:0.00182
# [20:53:30] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1154 extra nodes, 0 pruned nodes, max_depth=10
# [59]	eval-rmse:0.00177
# [20:53:45] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1418 extra nodes, 0 pruned nodes, max_depth=10
# [60]	eval-rmse:0.00173
# [20:54:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1024 extra nodes, 0 pruned nodes, max_depth=10
# [61]	eval-rmse:0.00169
# [20:54:15] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1408 extra nodes, 0 pruned nodes, max_depth=10
# [62]	eval-rmse:0.00166
# [20:54:30] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1360 extra nodes, 0 pruned nodes, max_depth=10
# [63]	eval-rmse:0.00164
# [20:54:45] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1020 extra nodes, 0 pruned nodes, max_depth=10
# [64]	eval-rmse:0.00161
# [20:55:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1328 extra nodes, 0 pruned nodes, max_depth=10
# [65]	eval-rmse:0.00160
# [20:55:17] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1436 extra nodes, 0 pruned nodes, max_depth=10
# [66]	eval-rmse:0.00159
# [20:55:33] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1124 extra nodes, 0 pruned nodes, max_depth=10
# [67]	eval-rmse:0.00157
# [20:55:52] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1224 extra nodes, 0 pruned nodes, max_depth=10
# [68]	eval-rmse:0.00156
# [20:56:07] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1092 extra nodes, 0 pruned nodes, max_depth=10
# [69]	eval-rmse:0.00156
# [20:56:22] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1324 extra nodes, 0 pruned nodes, max_depth=10
# [70]	eval-rmse:0.00155
# [20:56:37] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 960 extra nodes, 0 pruned nodes, max_depth=10
# [71]	eval-rmse:0.00155
# [20:56:53] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1332 extra nodes, 0 pruned nodes, max_depth=10
# [72]	eval-rmse:0.00154
# [20:57:08] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1058 extra nodes, 0 pruned nodes, max_depth=10
# [73]	eval-rmse:0.00154
# [20:57:23] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1240 extra nodes, 0 pruned nodes, max_depth=10
# [74]	eval-rmse:0.00154
# [20:57:39] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1350 extra nodes, 0 pruned nodes, max_depth=10
# [75]	eval-rmse:0.00153
# [20:57:54] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1226 extra nodes, 0 pruned nodes, max_depth=10
# [76]	eval-rmse:0.00153
# [20:58:09] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1126 extra nodes, 0 pruned nodes, max_depth=10
# [77]	eval-rmse:0.00153
# [20:58:25] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1528 extra nodes, 0 pruned nodes, max_depth=10
# [78]	eval-rmse:0.00153
# [20:58:41] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1454 extra nodes, 0 pruned nodes, max_depth=10
# [79]	eval-rmse:0.00153
# [20:58:56] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1194 extra nodes, 0 pruned nodes, max_depth=10
# [80]	eval-rmse:0.00153
# [20:59:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1388 extra nodes, 0 pruned nodes, max_depth=10
# [81]	eval-rmse:0.00153
# [20:59:27] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 958 extra nodes, 0 pruned nodes, max_depth=10
# [82]	eval-rmse:0.00153
# [20:59:42] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1668 extra nodes, 0 pruned nodes, max_depth=10
# [83]	eval-rmse:0.00153
# [20:59:58] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1062 extra nodes, 0 pruned nodes, max_depth=10
# [84]	eval-rmse:0.00153
# [21:00:13] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1156 extra nodes, 0 pruned nodes, max_depth=10
# [85]	eval-rmse:0.00153
# [21:00:28] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1290 extra nodes, 0 pruned nodes, max_depth=10
# [86]	eval-rmse:0.00153
# [21:00:44] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1454 extra nodes, 0 pruned nodes, max_depth=10
# [87]	eval-rmse:0.00153
# [21:01:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1402 extra nodes, 0 pruned nodes, max_depth=10
# [88]	eval-rmse:0.00153
# [21:01:15] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1262 extra nodes, 0 pruned nodes, max_depth=10
# [89]	eval-rmse:0.00153
# [21:01:31] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1352 extra nodes, 0 pruned nodes, max_depth=10
# [90]	eval-rmse:0.00153
# [21:01:47] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1396 extra nodes, 0 pruned nodes, max_depth=10
# [91]	eval-rmse:0.00153
# [21:02:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1398 extra nodes, 0 pruned nodes, max_depth=10
# [92]	eval-rmse:0.00153
# [21:02:18] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1158 extra nodes, 0 pruned nodes, max_depth=10
# [93]	eval-rmse:0.00153
# [21:02:34] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1654 extra nodes, 0 pruned nodes, max_depth=10
# [94]	eval-rmse:0.00153
# [21:02:49] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1132 extra nodes, 0 pruned nodes, max_depth=10
# [95]	eval-rmse:0.00153
# [21:03:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 1210 extra nodes, 0 pruned nodes, max_depth=10
# [96]	eval-rmse:0.00153
# Stopping. Best iteration:
# [86]	eval-rmse:0.00153

# %%
ypred = bst.predict(dtest, ntree_limit=bst.best_ntree_limit)
checkAcc(ypred, y_test)
# Out:
# direction prediction accuracy 0.625020795124662
# 0.625020795124662

# %%
matplotlib.rcParams['figure.dpi'] = 144
matplotlib.rcParams["figure.figsize"] = (10,10)
xgb.plot_importance(bst)
plt.show()

# %%
def xgboostRegressorProcess(dtrain,dval,dtest):

    
    param = {'max_depth': 8, 'eta': 0.1, 'verbosity':2,'subsample':0.5}
    param['nthread'] = 4
    param['eval_metric'] = 'rmse'

    evallist = [(dval, 'eval')]    
    
    num_round = 100
    bst = xgb.train(param, dtrain, num_round, evallist, early_stopping_rounds=10)
    

    ypred = bst.predict(dtest, ntree_limit=bst.best_ntree_limit)
    checkAcc(ypred, y_test)
    xgb.plot_importance(bst)
    plt.show()

# %% [markdown]
# ## Extreme Random Forest

# %%
extra_reg = ensemble.ExtraTreesRegressor()
gs = model_selection.GridSearchCV(
    extra_reg,
    {"n_estimators":range(10,101,10), 'min_samples_leaf': range(20,50,5),
    'min_samples_split': range(15,36,5) },
    cv=5,  # 5-fold cross validation
    n_jobs=4,  # run each hyperparameter in one of two parallel jobs
    scoring='r2',
    verbose = 5
)

# %%
gs.fit(X_val[:10000], y_val[:10000])
print ("Best: %f using %s" % (gs.best_score_, gs.best_params_))

# %%
extra_reg =ensemble.ExtraTreesRegressor(min_samples_split=30, n_estimators=40 ,min_samples_leaf= 35, n_jobs=-1,verbose=7)
extra_reg.fit(X_train, y_train)
pre1 = extra_reg.predict(X_test)
checkAcc(pre1, y_test)

# %%
extra_reg = ensemble.ExtraTreesRegressor(n_estimators=100,n_jobs=-2,verbose=7)
extra_reg.fit(X_train, y_train)
# Out:
# building tree 1 of 100building tree 2 of 100
#
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# [Parallel(n_jobs=-2)]: Done   2 tasks      | elapsed:  1.1min
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# [Parallel(n_jobs=-2)]: Done  26 tasks      | elapsed:  9.3min
# building tree 30 of 100
# building tree 31 of 100
# building tree 32 of 100
# building tree 33 of 100
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# [Parallel(n_jobs=-2)]: Done  66 tasks      | elapsed: 29.5min
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# [Parallel(n_jobs=-2)]: Done 100 out of 100 | elapsed: 48.3min finished
# ExtraTreesRegressor(bootstrap=False, criterion='mse', max_depth=None,
#           max_features='auto', max_leaf_nodes=None,
#           min_impurity_decrease=0.0, min_impurity_split=None,
#           min_samples_leaf=1, min_samples_split=2,
#           min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-2,
#           oob_score=False, random_state=None, verbose=7, warm_start=False)

# %%
X_test.isnull().values.any()
pre1 = extra_reg.predict(X_test)
checkAcc(pre1, y_test)
# Out:
# [Parallel(n_jobs=3)]: Done   2 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=3)]: Done  26 tasks      | elapsed:   11.1s
# [Parallel(n_jobs=3)]: Done  66 tasks      | elapsed:   27.9s
# [Parallel(n_jobs=3)]: Done 100 out of 100 | elapsed:   42.0s finished
# direction prediction accuracy 0.6187051451057252
# 0.6187051451057252

# %%
dic = dict(zip(X_train.columns,extra_reg.feature_importances_))
dicsort = sorted(dic.items(), key = lambda item: item[1], reverse = True)
dicsort
# Out:
# [('irregular_Mid_Last_diff_EMA', 0.22579712090471257),
#  ('regular_relevant_trend_ETHBTC', 0.073446089693609329),
#  ('regular_mid_ma_diff', 0.040477555136849287),
#  ('regular_current_trend_last_large_trend_ratio', 0.038358044733320613),
#  ('irregular_liquid_hour', 0.032691957871314535),
#  ('regular_Min_Max_Position', 0.02879584056591589),
#  ('regular_relevant_trend_BTCUSDT', 0.027217319485319802),
#  ('regular_current_trend', 0.024456640813372742),
#  ('regular_ma_diff', 0.02422503643967127),
#  ('regular_current_trend_last_trend_ratio', 0.020679487731581125),
#  ('regular_MA_Tick_Return', 0.020349011712941768),
#  ('regular_Last2_trend', 0.020148641335824977),
#  ('irregular_weighted_middle_price_diff', 0.019734385753624416),
#  ('regular_Trend_Speed_3', 0.019106292758419085),
#  ('irregular_weighted_middle_price_change', 0.018691296254152986),
#  ('regular_Ceiling_Floors_7', 0.01851612188650963),
#  ('regular_Ceiling_Floors_3', 0.017769229196983233),
#  ('regular_Ceiling_Floors_5', 0.017232941543198252),
#  ('regular_Ceiling_Floors_11', 0.017059277711226856),
#  ('irregular_liquid_orderbook_thickness', 0.01690247901939973),
#  ('regular_Ceiling_Floors_19', 0.016715680452527235),
#  ('regular_current_last2_ratio', 0.016642323533081226),
#  ('regular_current_trend_speed', 0.016071718544248114),
#  ('regular_last_last2_ratio', 0.015960761087006538),
#  ('regular_Ceiling_Floors_13', 0.015622586863809049),
#  ('regular_Ceiling_Floors_9', 0.015042722378741468),
#  ('regular_Ceiling_Floors_15', 0.014997700709926988),
#  ('regular_Order_Flow_MA', 0.0147409707426102),
#  ('regular_Ceiling_Floors_17', 0.014616317298192119),
#  ('regular_adjusted_current_trend', 0.011879862426129477),
#  ('regular_Consecutive_Large_Order_Flow', 0.011721394731745547),
#  ('irregular_adjusted_ask_bid_amount_ratio_EMA', 0.011393678009312944),
#  ('irregular_liquid_orderbook_density', 0.010577982700920663),
#  ('regular_liquid_current_amount', 0.010274984086995563),
#  ('irregular_liquid_rapid_change', 0.0088722431899526007),
#  ('regular_ma_diff_change', 0.0088613356015218407),
#  ('irregular_Large_Quote_EMA', 0.0083229719906931145),
#  ('irregular_liquid_orderbook_slope', 0.0082764037457305466),
#  ('irregular_ask_bid_amount_ratio_EMA', 0.0076543006993060013),
#  ('irregular_orderbook_slope_diff_EMA', 0.0074755070527927599),
#  ('irregular_liquid_rapid_inverse_change', 0.0074231094988227355),
#  ('irregular_liquid_update_rate', 0.0063182226504904168),
#  ('irregular_Consecutive_Large_Pressure', 0.0056413787394198663),
#  ('irregular_ask_Pressure', 0.0047029822319516867),
#  ('irregular_Dynamic_Pressure', 0.0044321106385249998),
#  ('irregular_bid_Pressure', 0.0041059798475981913)]
