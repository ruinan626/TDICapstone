# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import matplotlib
matplotlib.use('Agg')

# %%
#xgb = [0.625020795124662,0.6129992696823675,0.6132092475440115]
#extremerf = [0.6187051451057252,0.6329164644943078,0.605920694547304]

xgb = [0.625,0.613,0.613]
extremerf = [0.619,0.633,0.606]
name = ['ETHUSDT','BTCUSDT','ETHBTC']

# %%
labels = ['ETHUSDT','BTCUSDT','ETHBTC'] 
xgb = [0.625,0.613,0.613]
extremerf = [0.619,0.633,0.606]

x = np.arange(len(labels))  
width = 0.35 
fig = plt.figure()

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, xgb, width, label='XGBoost')
rects2 = ax.bar(x + width/2, extremerf, width, label='Extreme Random Forest')


ax.set_ylabel('Direction Prediction Accuracy')
ax.set_title('Accuracy by groups')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend(loc='lower right')



def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3), 
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

fig.tight_layout( )

plt.figure(figsize=(4,6))
plt.show()
# Out:
# /Users/ruinanlu/Documents/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

# %%
labels = ['ETHUSDT','BTCUSDT','ETHBTC'] 
extremerf = [0.619,0.633,0.606]

x = np.arange(len(labels))  
width = 0.35 
fig = plt.figure()

fig, ax = plt.subplots()
rects2 = ax.bar(x - width/2, extremerf, width, label='Extreme Random Forest')

ax.set_ylabel('Direction Prediction Accuracy')
ax.set_title('ExtremeRandomForest Accuracy')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend(loc='lower right')


autolabel(rects2)


fig.tight_layout( )

plt.figure(figsize=(4,6))
plt.show()
# Out:
# /Users/ruinanlu/Documents/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
labels = ['ETHUSDT','BTCUSDT','ETHBTC'] 
xgb = [0.625,0.613,0.613]

x = np.arange(len(labels))  
width = 0.35 
fig = plt.figure()

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, xgb, width, label='XGBoost')


ax.set_ylabel('Direction Prediction Accuracy')
ax.set_title('XGBoost Accuracy')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend(loc='lower right')


autolabel(rects1)


fig.tight_layout( )

plt.figure(figsize=(4,6))
plt.show()
# Out:
# /Users/ruinanlu/Documents/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
featureimportanceETHBTC = [('regular_Ceiling_Floors_15', (0, 12)),
 ('regular_Last2_trend', (1, 6)),
 ('regular_current_trend_last_large_trend_ratio', (2, 1)),
 ('regular_Trend_Speed_3', (3, 10)),
  ('irregular_liquid_hour', (6, 2)),
 ('regular_last_last2_ratio', (7, 13)),
 ('regular_Ceiling_Floors_9', (8, 9)),
 ('regular_Ceiling_Floors_19', (11, 11)),
 ('regular_Ceiling_Floors_5', (13, 7)),
('irregular_Mid_Last_diff_EMA', (34, 0)),
('irregular_liquid_orderbook_density', (14, 4)),
('regular_mid_ma_diff', (26, 3))]

# %%
featureimportanceETHBTC
# Out:
# [('regular_Ceiling_Floors_15', (0, 12)),
#  ('regular_Last2_trend', (1, 6)),
#  ('regular_current_trend_last_large_trend_ratio', (2, 1)),
#  ('regular_Trend_Speed_3', (3, 10)),
#  ('irregular_liquid_hour', (6, 2)),
#  ('regular_last_last2_ratio', (7, 13)),
#  ('regular_Ceiling_Floors_9', (8, 9)),
#  ('regular_Ceiling_Floors_19', (11, 11)),
#  ('regular_Ceiling_Floors_5', (13, 7)),
#  ('irregular_Mid_Last_diff_EMA', (34, 0)),
#  ('irregular_liquid_orderbook_density', (14, 4)),
#  ('regular_mid_ma_diff', (26, 3))]

# %%
'regular_current_trend_last_large_trend_ratio',
'regular_Last2_trend',
'irregular_liquid_hour',
'regular_Ceiling_Floors_15',
# Out:
# ('regular_Ceiling_Floors_15',)

# %% [markdown]
# 'regular_Trend_Speed_3',

# %% [markdown]
# rf top 3 features:
#
# irregular_Mid_Last_diff_EMA
# 'irregular_liquid_hour',
# 'regular_mid_ma_diff',

# %% [markdown]
# important in XGBoost
# ('irregular_Large_Quote_EMA', (4, 30)),
#  ('regular_relevant_trend_BTCUSDT', (5, 22)),
